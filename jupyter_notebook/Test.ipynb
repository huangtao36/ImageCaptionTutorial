# %%
from easydict import EasyDict as edit
import torch
import numpy as np
import os
import re
import pickle
from torchvision import transforms
from build_vocab import Vocabulary
from model import EncoderCNN, DecoderRNN
from PIL import Image

# %%
args = edit({
    "image": "./",
    "device": torch.device('cuda: 0' if torch.cuda.is_available() else 'cpu'),
    "video_path": './2fps_sample_video',
    "encoder_path": './models/encoder-5-3000.ckpt',
    "decoder_path": './models/decoder-5-3000.ckpt',
    "vocab_path": './data/vocab.pkl',
    "embed_size": 256,
    "hidden_size": 512,
    "num_layers": 1,
})

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406),
                        (0.229, 0.224, 0.225))
])

# %%
with open(args.vocab_path, 'rb') as f:
    vocab = pickle.load(f)

# %%
encoder = EncoderCNN(args.embed_size).eval()
decoder = DecoderRNN(args.embed_size, args.hidden_size, len(vocab), args.num_layers)

encoder = encoder.to(args.device)
decoder = decoder.to(args.device)

# %%
encoder.load_state_dict(torch.load(args.encoder_path))
decoder.load_state_dict(torch.load(args.decoder_path))

# %%
args.image = './png/1.jpg'

# %%
def load_image(image_path, transform=None):
    image = Image.open(image_path).convert('L')
    image = image.resize([224, 224], Image.LANCZOS)
    
    if transform is not None:
        image = transform(image).unsqueeze(0)
    
    image = torch.cat((image, image, image), 1)
    return image

# %%
for video_name in os.listdir(args.video_path):
    print(video_name)
    video_path = os.path.join(args.video_path, video_name)
    frame_list = os.listdir(video_path)
    frame_list = sorted(frame_list, key=lambda i:int(re.match(r'(\d+)',i).group()))
    
    out_list = []
    for i, frame in enumerate(frame_list):
        frame_file = os.path.join(video_path, frame)
        
        # Prepare an image
        image = load_image(frame_file, transform)
        image_tensor = image.to(args.device)

        # Generate an caption from the image
        feature = encoder(image_tensor)
        sampled_ids, out_feature_list = decoder.sample(feature)
        out_list.append(out_feature_list)
        sampled_ids = sampled_ids[0].cpu().numpy()

        # Convert word_ids to words
        sampled_caption = []
        for word_id in sampled_ids:
            word = vocab.idx2word[word_id]
            sampled_caption.append(word)
            if word == '<end>':
                break
        sentence = ' '.join(sampled_caption)
        print("{}, {}".format(i, sentence))
    break
# Out:
# EYqVtI9YWJA
# 0, <start> a black and white photo of a pair of scissors . <end>
# 1, <start> a white bed with a white comforter and a black cat laying on it . <end>
# 2, <start> a couple of pictures of a building with a clock . <end>
# 3, <start> a sign that says <unk> <unk> <unk> <unk> <unk> . <end>
# 4, <start> a sign for a barber shop with a clock on it . <end>
# 5, <start> a sign for a barber shop with a clock on it . <end>
# 6, <start> a sign for a <unk> <unk> <unk> <unk> <unk> <unk> <unk> . <end>
# 7, <start> a sign that says <unk> street and a building in the background . <end>
# 8, <start> a sign for a barber shop with a sign on it . <end>
# 9, <start> a sign for a barber shop with a sign on it . <end>
# 10, <start> a sign for a barber shop with a sign on it . <end>
# 11, <start> a sign for a barber shop with a sign on it . <end>
# 12, <start> a sign for a barber shop with a sign on it . <end>
# 13, <start> a street sign with a street sign on top of it . <end>
# 14, <start> a street sign with a street sign on top of it . <end>
# 15, <start> a group of men standing next to each other . <end>
# 16, <start> a group of men standing next to each other . <end>
# 17, <start> two men in suits and ties standing in front of a clock . <end>
# 18, <start> a man and woman standing next to each other . <end>
# 19, <start> a man and a woman standing next to each other . <end>
# 20, <start> a man and a woman standing next to each other . <end>
# 21, <start> a man and a woman standing next to each other . <end>
# 22, <start> a man and woman pose for a picture in front of a clock . <end>
# 23, <start> a man and a woman standing next to each other . <end>
# 24, <start> a man and a woman standing next to each other . <end>
# 25, <start> a man and a woman standing next to each other . <end>
# 26, <start> a man and a woman standing next to each other . <end>
# 27, <start> a man and a woman standing next to each other . <end>
# 28, <start> a man and woman standing next to each other . <end>
# 29, <start> a man holding a glass of wine in front of a woman holding a glass . <end>
# 30, <start> a man in a suit and tie standing in front of a building . <end>
# 31, <start> a man and woman standing next to each other . <end>
# 32, <start> a man and woman standing in front of a clock . <end>
# 33, <start> a man and a woman standing next to each other . <end>
# 34, <start> a woman is holding a sign in front of a store . <end>
# 35, <start> a man sitting in a chair in front of a store window . <end>
# 36, <start> a black and white photo of a train station . <end>
# 37, <start> a large clock on a building in a city . <end>
# 38, <start> a black and white photo of a man on a skateboard . <end>
# 39, <start> a black and white photo of a clock on a building . <end>
# 40, <start> a black and white photo of a man on a skateboard . <end>
# 41, <start> a black and white photo of a man on a skateboard . <end>
# 42, <start> a train is traveling down the tracks in a large city . <end>
# 43, <start> a train station with a train station with a train on the tracks . <end>
# 44, <start> a kitchen with a lot of people cooking in it <end>
# 45, <start> a woman is standing in front of a table with a microphone . <end>
# 46, <start> a woman is standing in a kitchen with a dog in the background . <end>
# 47, <start> a man is holding a knife and a bird in his hand . <end>
# 48, <start> a man is doing a trick on a skateboard . <end>
# 49, <start> a man in a hat is standing on a skateboard . <end>
# 50, <start> a man in a suit and tie with a woman in a suit and hat . <end>
# 51, <start> a man in a suit and tie standing in front of a crowd . <end>
# 52, <start> a man in a suit and tie standing in front of a microphone . <end>
# 53, <start> a man in a suit and tie holding a glass of wine . <end>
# 54, <start> a man in a suit and tie is smiling . <end>
# 55, <start> a man in a suit and tie standing in front of a group of people . <end>
# 56, <start> a man in a suit and tie with a microphone <end>
# 57, <start> a man in a suit and tie is looking at a book . <end>
# 58, <start> a man in a suit and tie is holding a knife . <end>
# 59, <start> a man in a suit and tie is looking at a book . <end>
# 60, <start> a man in a suit and tie with a woman in a black and white photo . <end>
# 61, <start> a man in a suit and tie with a microphone <end>
# 62, <start> a man in a suit and tie with a microphone <end>
# 63, <start> a black and white photo of a man playing guitar hero <end>
# 64, <start> a person is standing in front of a horse . <end>
# 65, <start> a man is standing in front of a large building . <end>
# 66, <start> a man is standing next to a horse in a field . <end>
# 67, <start> a man is standing on a skateboard in a parking lot . <end>
# 68, <start> a group of people standing around a table with a large horse . <end>
# 69, <start> a black and white photo of a man standing next to a horse . <end>
# 70, <start> a woman is standing next to a horse in a parking lot . <end>
# 71, <start> a black and white photo of a bicycle rider . <end>
# 72, <start> a bicycle rider is on a bicycle in front of a store . <end>
# 73, <start> a man is standing on a bicycle with a dog . <end>
# 74, <start> a man is riding a motorcycle with a dog on the side . <end>
# 75, <start> a man in a suit and tie standing in front of a microphone . <end>
# 76, <start> a man in a suit and tie standing in front of a building . <end>
# 77, <start> a man in a suit and tie standing in front of a group of people . <end>
# 78, <start> a man in a suit and tie standing in front of a group of people . <end>
# 79, <start> a man in a suit and tie is smiling <end>
# 80, <start> a man in a suit and tie with a microphone <end>
# 81, <start> a man in a suit and tie with a microphone <end>
# 82, <start> a man in a suit and tie with a microphone <end>
# 83, <start> a man and woman standing next to each other . <end>
# 84, <start> a person is sitting on a bench in a city . <end>
# 85, <start> a man is standing on a street corner in front of a building . <end>
# 86, <start> a man is standing on a stage with a microphone . <end>
# 87, <start> a man standing on a stage with a microphone in front of him . <end>
# 88, <start> a black and white photo of a man on a motorcycle . <end>
# 89, <start> a man sitting on a bench with a bicycle on it . <end>
# 90, <start> a man is standing in front of a large screen . <end>
# 91, <start> a man sitting on a horse in front of a building . <end>
# 92, <start> a man is sitting on a horse in front of a crowd . <end>
# 93, <start> a man is riding a bike in front of a car . <end>
# 94, <start> a man sitting on a horse in front of a building . <end>
# 95, <start> a man riding a bike with a dog on the back of it . <end>
# 96, <start> a man in a suit and tie standing in front of a building . <end>
# 97, <start> a man in a suit and tie standing in front of a building . <end>
# 98, <start> a man in a suit and tie standing in front of a building . <end>
# 99, <start> a man in a suit and tie standing in front of a building . <end>
# 100, <start> a black and white photo of a man in a suit and tie . <end>
# 101, <start> a man in a suit and tie standing in front of a building . <end>
# 102, <start> a man with a baseball bat standing in front of a crowd . <end>
# 103, <start> a man in a suit and tie standing in front of a building . <end>
# 104, <start> a man in a suit and tie is standing in front of a building . <end>
# 105, <start> a man in a tie and a hat is talking on a phone . <end>
# 106, <start> a man in a tie and a hat is talking on a phone . <end>
# 107, <start> a man in a suit and tie holding a glass of wine . <end>
# 108, <start> a man in a suit and tie standing in front of a building . <end>
# 109, <start> a man in a suit and tie standing in front of a building . <end>
# 110, <start> a man in a suit and tie standing in front of a building . <end>
# 111, <start> a man in a suit and tie standing in front of a window . <end>
# 112, <start> a man in a suit and tie standing in front of a crowd . <end>
# 113, <start> a man and woman standing next to each other . <end>
# 114, <start> a man in a hat is holding a baseball bat . <end>
# 115, <start> a man is standing in front of a window . <end>
# 116, <start> a man standing in a field holding a frisbee . <end>
# 117, <start> a man standing in front of a window with a frisbee in it 's mouth . <end>
# 118, <start> a woman holding a tennis racquet on a tennis court . <end>
# 119, <start> a woman is holding a tennis racket in her hand . <end>
# 120, <start> a woman holding a large white umbrella in her hand . <end>
# 121, <start> a group of people standing around a table with a cake . <end>
# 122, <start> a group of people standing around a table with a cake . <end>
# 123, <start> a group of people standing around a tennis court . <end>
# 124, <start> a group of people standing around a tennis court . <end>
# 125, <start> a group of people standing around a table with a cake . <end>
# 126, <start> a group of people standing around a horse drawn carriage . <end>
# 127, <start> a group of people standing around a table with a cake . <end>
# 128, <start> a man in a suit and tie with a woman in a suit and hat . <end>
# 129, <start> a man in a suit and tie is looking at a cell phone . <end>
# 130, <start> a man in a suit and tie is looking at a phone . <end>
# 131, <start> a man in a suit and tie is holding a glass of wine . <end>
# 132, <start> a man in a suit and tie is standing in front of a mirror . <end>
# 133, <start> a man and woman standing next to each other . <end>
# 134, <start> a man and woman standing next to each other . <end>
# 135, <start> a man in a suit and tie standing in front of a building . <end>
# 136, <start> a man and woman standing next to each other . <end>
# 137, <start> a man in a suit and tie holding a glass of wine . <end>
# 138, <start> a man in a suit and tie is holding a glass of wine . <end>
# 139, <start> a man in a suit and tie is holding a glass of wine . <end>
# 140, <start> a man in a suit and tie is looking at a book . <end>
# 141, <start> a man in a suit and tie with a woman in a suit and hat . <end>
# 142, <start> a man and woman standing next to each other . <end>
# 143, <start> a man in a suit and tie standing in front of a building . <end>
# 144, <start> a man in a suit and tie standing in front of a crowd . <end>
# 145, <start> a man and woman standing next to each other . <end>
# 146, <start> a man and woman standing next to each other . <end>
# 147, <start> a man in a suit and tie standing in front of a building . <end>
# 148, <start> a man in a suit and tie standing next to a woman . <end>
# 149, <start> a man in a suit and tie holding a glass of wine . <end>
# 150, <start> a man in a suit and tie standing in front of a group of people . <end>
# 151, <start> a man in a suit and tie standing in front of a building . <end>
# 152, <start> a man in a suit and tie standing in front of a woman . <end>
# 153, <start> a man in a suit and tie standing in front of a building . <end>
# 154, <start> a man is holding a frisbee in his hand . <end>
# 155, <start> a man is standing on a skateboard in a dark room . <end>
# 156, <start> a man is sitting on a bench in a crowded area . <end>
# 157, <start> a group of people standing around a table with a large group of people . <end>
# 158, <start> a large group of people are standing around a table . <end>
# 159, <start> a man is standing on a skateboard in a crowd of people . <end>
# 160, <start> a woman is sitting on a bench in a city . <end>
# 161, <start> a group of people standing around a motorcycle . <end>
# 162, <start> a group of people standing around a table with a large vase . <end>
# 163, <start> a man is sitting at a table with a microphone . <end>
# 164, <start> a man is sitting on a bench in a baseball game . <end>
# 165, <start> a man is sitting on a bench in a city . <end>
# 166, <start> a man in a suit is standing in front of a crowd . <end>
# 167, <start> a black and white photo of a man in a suit and hat . <end>
# 168, <start> a man in a black suit is standing on a skateboard . <end>
# 169, <start> a man is holding a glass of wine in his hand . <end>
# 170, <start> a man is sitting on a bench in a city . <end>
# 171, <start> a black and white photo of a man on a bike . <end>
# 172, <start> a group of people standing around a table with a wine glass . <end>
# 173, <start> a man in a suit and tie with a microphone <end>
# 174, <start> a man in a suit and tie with a microphone <end>
# 175, <start> a man in a suit and tie with a woman in a suit and hat . <end>
# 176, <start> a man in a suit and tie with a woman in a suit and hat . <end>
# 177, <start> a man in a suit and tie holding a glass of wine . <end>
# 178, <start> a man in a suit and tie holding a glass of wine . <end>
# 179, <start> a man in a suit and tie holding a glass of wine . <end>
# 180, <start> a man and woman standing next to each other . <end>
# 181, <start> a man holding a glass of wine in front of a woman . <end>
# 182, <start> a man in a suit and tie standing in front of a microphone . <end>
# 183, <start> a man in a suit and tie with a woman in a suit and hat . <end>
# 184, <start> a man in a suit and tie with a microphone <end>
# 185, <start> a man in a suit and tie standing in front of a group of people . <end>
# 186, <start> a man in a suit and tie with a woman in a suit and hat . <end>
# 187, <start> a man in a suit and tie with a woman in a black and white photo . <end>
# 188, <start> a man in a suit and tie with a woman in a suit and hat . <end>
# 189, <start> a man in a suit and tie is smiling . <end>
# 190, <start> a man in a suit and tie holding a glass of wine . <end>
# 191, <start> a man in a suit and tie holding a glass of wine . <end>
# 192, <start> a man in a suit and tie is looking at a book . <end>
# 193, <start> a man in a suit and tie is looking at a woman . <end>
# 194, <start> a man is standing on a bicycle in front of a store . <end>
# 195, <start> a person on a skateboard does a trick on a ramp . <end>
# 196, <start> a man in a black shirt is playing tennis <end>
# 197, <start> a man riding a bike with a dog on a leash . <end>
# 198, <start> a black and white photo of a man on a bike . <end>
# 199, <start> a black and white photo of a man on a motorcycle . <end>
# 200, <start> a black and white photo of a man on a motorcycle . <end>
# 201, <start> a motorcycle is parked in a parking lot . <end>
# 202, <start> a motorcycle is parked on a sidewalk in front of a crowd . <end>
# 203, <start> a man riding a motorcycle with a man on the back . <end>
# 204, <start> a man is riding a motorcycle with a man on the side . <end>
# 205, <start> a man is sitting on a motorcycle with a dog on the back . <end>
# 206, <start> a man is sitting on a motorcycle with a crowd of people . <end>
# 207, <start> a man riding a motorcycle with a man on the back . <end>
# 208, <start> a man riding a motorcycle down a street . <end>
# 209, <start> a man sitting on a bike with a dog on the back . <end>
# 210, <start> a man riding a bike with a dog on the back . <end>
# 211, <start> a man riding a bike down a street next to a woman . <end>
# 212, <start> a man riding a motorcycle down a street . <end>
# 213, <start> a man riding a motorcycle down a street . <end>
# 214, <start> a man is standing on a skateboard ramp . <end>
# 215, <start> a black and white photo of a man on a bicycle . <end>
# 216, <start> a man riding a bike down a street next to a woman . <end>
# 217, <start> a motorcycle parked on the side of a street . <end>
# 218, <start> a man riding a motorcycle with a woman on the back . <end>
# 219, <start> a man riding a motorcycle with a woman on the back . <end>
# 220, <start> a black and white photo of a man in a suit and tie . <end>
# 221, <start> a man is standing on a stage with a microphone . <end>
# 222, <start> a black and white photo of a man in a suit and tie <end>
# 223, <start> a black and white photo of a motorcycle with a clock on the side . <end>
# 224, <start> a motorcycle parked in front of a building . <end>
# 225, <start> a man sitting on a motorcycle in front of a car . <end>
# 226, <start> a black and white photo of a man in a suit and hat . <end>
# 227, <start> a man is standing on a bicycle in front of a bus . <end>
# 228, <start> a black and white photo of a man standing next to a motorcycle . <end>
# 229, <start> a man riding a bike with a dog on the back . <end>
# 230, <start> a man in a suit and tie with a microphone <end>
# 231, <start> a man in a suit and tie holding a glass of wine . <end>
# 232, <start> a man and woman standing next to each other . <end>
# 233, <start> a man in a suit and tie with a woman in a black shirt and a black hat .
# 234, <start> a man in a tie and a woman in a white shirt and a black tie . <end>
# 235, <start> a man and woman standing next to each other . <end>
# 236, <start> a man in a suit and tie with a woman in a black shirt and a black background .
# 237, <start> a man in a suit and tie holding a glass of wine . <end>
# 238, <start> a man in a suit and tie with a microphone <end>
# 239, <start> a man in a suit and tie with a microphone <end>
# 240, <start> a man in a suit and tie holding a glass of wine . <end>
# 241, <start> a man in a suit and tie holding a glass of wine . <end>
# 242, <start> a man in a suit and tie holding a glass of wine . <end>
# 243, <start> a man holding a glass of wine in his hand . <end>
# 244, <start> a man in a suit and tie is looking at a cell phone . <end>
# 245, <start> a man in a suit and tie holding a glass of wine . <end>
# 246, <start> a man in a suit and tie with a tie . <end>
# 247, <start> a man in a tie and a woman in a white background . <end>
# 248, <start> a man in a suit and tie holding a glass of wine . <end>
# 249, <start> a man in a suit and tie holding a knife . <end>
# 250, <start> a man in a suit and tie holding a glass of wine . <end>
# 251, <start> a man in a suit and tie with a microphone <end>
# 252, <start> a man in a suit and tie holding a glass of wine . <end>
# 253, <start> a man in a suit and tie with a microphone <end>
# 254, <start> a man in a suit and tie with a woman in a black shirt and a black hat .
# 255, <start> a man in a suit and tie with a woman in a room . <end>
# 256, <start> a man in a suit and tie standing in front of a group of people . <end>
# 257, <start> a man in a suit and tie with a woman in a black and white photo . <end>
# 258, <start> a man in a suit and tie with a woman in a black and white photo . <end>
# 259, <start> a man in a suit and tie holding a glass of wine . <end>
# 260, <start> a man in a suit and tie holding a glass of wine . <end>
# 261, <start> a man in a suit and tie holding a glass of wine . <end>
# 262, <start> a man in a suit and tie is holding a glass of wine . <end>
# 263, <start> a man in a suit and tie holding a glass of wine . <end>
# 264, <start> a black and white photo of a man on a motorcycle . <end>
# 265, <start> a black and white photo of a man and woman on a bike . <end>
# 266, <start> a black and white photo of a man standing next to a motorcycle . <end>
# 267, <start> a black and white photo of a man on a skateboard . <end>
# 268, <start> a clock on a building wall with a building in the background . <end>
# 269, <start> a man is sitting on a bench with a clock . <end>
# 270, <start> a man is sitting on a bench in front of a building . <end>
# 271, <start> a man is standing in front of a large screen . <end>
# 272, <start> a man is sitting on a bench in front of a large building . <end>
# 273, <start> a person standing on a street with a cell phone . <end>
# 274, <start> a person jumping a skate board in the air <end>
# 275, <start> a man is standing on a skateboard in the street . <end>
# 276, <start> a man is standing next to a motorcycle . <end>
# 277, <start> a man is sitting on a bench with a skateboard . <end>
# 278, <start> a person that is on a skateboard in a parking lot . <end>
# 279, <start> a couple of birds sitting on top of a wooden table . <end>
# 280, <start> a person is holding a knife and fork to cut a piece of paper . <end>
# 281, <start> a person on a motorcycle in front of a building . <end>
# 282, <start> a man riding a bike down a street next to a building . <end>
# 283, <start> a man is riding a skateboard on a ramp . <end>
# 284, <start> a man is sitting on a motorcycle in front of a building . <end>
# 285, <start> a man is sitting on a motorcycle in front of a building . <end>
# 286, <start> a man riding a motorcycle with a man on top of it . <end>
# 287, <start> a man sitting on a motorcycle in front of a car . <end>
# 288, <start> a black and white photo of a man standing next to a black and white photo . <end>
# 289, <start> a clock on a pole in front of a store . <end>
# 290, <start> a clock on a pole in a city . <end>
# 291, <start> a man riding a bike with a dog on the back of it . <end>
# 292, <start> a motorcycle parked on a sidewalk in front of a building . <end>
# 293, <start> a black and white photo of a man walking with a cow . <end>
# 294, <start> a black and white photo of a person riding a motorcycle <end>
# 295, <start> a person riding a bike on a street with a dog on a leash . <end>
# 296, <start> a man and woman standing next to each other . <end>
# 297, <start> a man in a suit and tie holding a glass of wine . <end>
# 298, <start> a man and woman standing next to each other . <end>
# 299, <start> a man and woman standing next to each other . <end>
# 300, <start> a man and woman standing next to each other . <end>
# 301, <start> a man in a suit and tie standing in front of a group of people . <end>
# 302, <start> a man in a suit and tie standing in front of a group of people . <end>
# 303, <start> a man in a suit and tie is looking at a book . <end>
# 304, <start> a man in a suit and tie standing in front of a microphone . <end>
# 305, <start> two men in suits and ties standing in front of a building . <end>
# 306, <start> a man in a suit and tie standing in front of a group of people . <end>
# 307, <start> a group of men standing next to each other . <end>
# 308, <start> a man in a suit and tie standing in front of a group of people . <end>
# 309, <start> a black and white photo of a man in a suit and tie . <end>
# 310, <start> a man in a suit and tie is looking at a woman . <end>
# 311, <start> a man wearing a hat and a tie . <end>
# 312, <start> a man in a suit and tie standing in front of a building . <end>
# 313, <start> a man in a suit and tie is standing in front of a clock . <end>
# 314, <start> a man in a suit and tie is standing in front of a clock . <end>
# 315, <start> a man in a suit and tie is looking at a clock . <end>
# 316, <start> a man in a suit and tie standing in front of a building . <end>
# 317, <start> a black and white photo of a man in a suit and tie <end>
# 318, <start> a black and white photo of a man in a suit and tie <end>
# 319, <start> a man is sitting on a motorcycle in the middle of the street . <end>
# 320, <start> a man is riding a motorcycle in a parking lot . <end>
# 321, <start> a man is standing next to a motorcycle . <end>
# 322, <start> a man is riding a skateboard in a parking lot . <end>
# 323, <start> a man riding a skateboard down a street . <end>
# 324, <start> a man riding a skateboard down a street . <end>
# 325, <start> a person riding a bike in front of a building . <end>
# 326, <start> a man riding a skateboard down a street . <end>
# 327, <start> a man is standing in front of a large clock . <end>
# 328, <start> a black and white photo of a street sign . <end>
# 329, <start> a man is standing on a motorcycle in front of a building . <end>
# 330, <start> a man riding a bike down a street next to a large building . <end>
# 331, <start> a man riding a bike in front of a large building . <end>
# 332, <start> a person with a luggage cart on a street . <end>
# 333, <start> a man riding a horse in front of a building . <end>
# 334, <start> a man is standing next to a motorcycle . <end>
# 335, <start> a man is standing on a motorcycle in a parking lot . <end>
# 336, <start> a man is standing next to a motorcycle . <end>
# 337, <start> a black and white photo of a man on a motorcycle . <end>
# 338, <start> a motorcycle rider is parked on a sidewalk . <end>
# 339, <start> a black and white photo of a motorcycle parked in a driveway . <end>
# 340, <start> a man is doing a trick on a skateboard . <end>
# 341, <start> a person is walking in the rain with an umbrella . <end>
# 342, <start> a person is walking in the rain with an umbrella . <end>
# 343, <start> a man in a black suit and a black hat and a black hat <end>
# 344, <start> a man is walking down a street with a skateboard . <end>
# 345, <start> a man is skateboarding down a street with a crowd watching . <end>
# 346, <start> a black and white photo of a person holding a tennis racket . <end>
# 347, <start> a man in a suit and tie is looking at a menu . <end>
# 348, <start> a man and woman standing next to each other . <end>
# 349, <start> a man in a suit and tie standing in front of a window . <end>
# 350, <start> a man and a woman standing next to each other . <end>
# 351, <start> a black and white photo of a city street . <end>
# 352, <start> a black and white photo of a man in a suit and hat . <end>
# 353, <start> a black and white photo of a man on a skateboard . <end>
# 354, <start> a man riding a bike with a dog on the back . <end>
# 355, <start> a man riding a bike with a dog on a leash . <end>
# 356, <start> a man riding a horse on a city street . <end>
# 357, <start> a group of people standing around a tennis court . <end>
# 358, <start> a group of people watching a skateboarder do a trick . <end>
# 359, <start> a man riding a skateboard down a street . <end>
# 360, <start> a group of people standing around a tennis court . <end>
# 361, <start> a group of people standing around a table with a cake . <end>
# 362, <start> a group of people standing around a table with a umbrella . <end>
# 363, <start> a group of people standing around a table with a horse and a basket . <end>
# 364, <start> a black and white photo of a man in a kitchen . <end>
# 365, <start> a man is standing on a skateboard in front of a crowd . <end>
# 366, <start> a man in a white shirt and black pants is on a skateboard . <end>
# 367, <start> a group of people standing around a table with a cake . <end>
# 368, <start> a man is standing in front of a large crowd . <end>
# 369, <start> a man in a suit and tie holding a microphone . <end>
# 370, <start> a man in a suit and tie holding a microphone . <end>
# 371, <start> a black and white photo of a man in a suit and tie . <end>
# 372, <start> a black and white photo of a man on a skateboard . <end>
# 373, <start> a black and white photo of a man in a suit and tie . <end>
# 374, <start> a black and white photo of a man in a suit and hat . <end>
# 375, <start> a black and white photo of a man in a suit and tie . <end>
# 376, <start> a woman is holding a sign that says `` <unk> '' . <end>
# 377, <start> a woman is standing in front of a store . <end>
# 378, <start> a collage of pictures of a woman holding a sign . <end>
# 379, <start> a group of people standing around a sign in a city . <end>
# 380, <start> a man in a hat is standing in front of a store . <end>
# 381, <start> a woman is holding a glass of wine in her hand . <end>
# 382, <start> a man is holding a sign that says `` <unk> '' . <end>
# 383, <start> a man in a suit and tie is looking at a menu . <end>
# 384, <start> a street sign on a pole on a city street . <end>
# 385, <start> a black and white photo of a street sign and a building <end>
# 386, <start> a black and white photo of a street sign . <end>
# 387, <start> a black and white photo of a building with a clock . <end>
# 388, <start> a dark night with a dark colored night sky . <end>
# 389, <start> a dark night with a dark colored light . <end>
# 390, <start> a dark night with a dark colored light . <end>
# 391, <start> a dark night with a dark colored light . <end>
# 392, <start> a close up of a dark colored wall with a dark background <end>
# 393, <start> a close up of a dark colored wall with a dark background <end>
# 394, <start> a close up of a dark colored wall with a dark background <end>

# %%
fea = torch.stack(out_list[0]).data.cpu()

# %%
fea.shape
# Out:
# torch.Size([20, 1, 9956])

# %%
# 4, <start> a man holding a sign that says `` <unk> '' on the screen . <end>
# 5, <start> a man holding a sign that says `` <unk> '' on the screen . <end>
# 6, <start> a man and woman standing in front of a large screen . <end>
# 7, <start> a man holding a sign that says `` <unk> '' on the screen . <end>
vocab('and')
# Out:
# 7
